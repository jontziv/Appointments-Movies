# %% [markdown]
# ## ML Regression Project (XGBoost)

# %% [markdown]
# ### Project Scenario

# %% [markdown]
# ### Load and Inspect the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movies.csv")
df
# Out:
#                    title main_genre  belongs_to_collection  budget  \
# 0        Central Station      Drama                  False     2.9
# 1              Hard Rain   Thriller                  False    70.0
# 2             Half Baked     Comedy                  False     8.0
# 3     Great Expectations     Comedy                  False    25.0
# 4            Buffalo '66    Romance                  False     1.5
# ...                  ...        ...                    ...     ...
# 3661       Atomic Blonde     Action                  False    30.0
# 3662     The Emoji Movie     Comedy                  False    50.0
# 3663      The Dark Tower     Action                  False    60.0
# 3664          Wind River     Action                  False    11.0
# 3665              Kidnap      Drama                  False    21.0
#
#          revenue  production_companies  vote_average  popularity  runtime  \
# 0       5.596708                   3.0           7.6    4.919716    113.0
# 1      19.870567                   9.0           5.5    6.363405     97.0
# 2      17.460020                   1.0           6.4    7.022548     82.0
# 3      55.494066                   2.0           6.4    9.941228    111.0
# 4       2.375097                   NaN           7.2    9.167761    110.0
# ...          ...                   ...           ...         ...      ...
# 3661   90.007945                   5.0           6.1   14.455104    115.0
# 3662   66.913939                   2.0           5.8   33.694599     86.0
# 3663   71.000000                   4.0           5.7   50.903593     95.0
# 3664  184.770205                   3.0           7.4   40.796775    111.0
# 3665   24.527158                   7.0           6.0   20.214579     95.0
#
#       cast_size  crew_size      cast_tr  director_tr  production_company_tr  \
# 0            19         43     0.000000     0.000000               0.000000
# 1            10         82  2361.750386    12.890752           14585.748889
# 2            12          8   119.943461    44.442512           13181.546450
# 3            10          6   726.339145     0.000000           10393.573468
# 4            26         13   366.582721     0.000000                    NaN
# ...         ...        ...          ...          ...                    ...
# 3661         23         96  5208.358646     0.000000               0.208588
# 3662         33         46  2120.117991    30.000000           31840.881695
# 3663         50        199  3767.974906     7.594693            4528.739344
# 3664         22         18  2159.066587     0.000000             171.539887
# 3665         24         60  2167.482988     0.000000            1993.945221
#
#       English  title_length  rel_year rel_month
# 0       False            14      1998   January
# 1        True             8      1998   January
# 2        True             9      1998   January
# 3        True            17      1998   January
# 4        True            10      1998   January
# ...       ...           ...       ...       ...
# 3661     True            12      2017      July
# 3662     True            13      2017      July
# 3663     True            12      2017    August
# 3664     True             9      2017    August
# 3665     True             6      2017    August
#
# [3666 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3666 entries, 0 to 3665
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  3666 non-null   object
#  1   main_genre             3658 non-null   object
#  2   belongs_to_collection  3666 non-null   bool
#  3   budget                 3666 non-null   float64
#  4   revenue                3666 non-null   float64
#  5   production_companies   3521 non-null   float64
#  6   vote_average           3662 non-null   float64
#  7   popularity             3666 non-null   float64
#  8   runtime                3654 non-null   float64
#  9   cast_size              3666 non-null   int64
#  10  crew_size              3666 non-null   int64
#  11  cast_tr                3657 non-null   float64
#  12  director_tr            3661 non-null   float64
#  13  production_company_tr  3521 non-null   float64
#  14  English                3666 non-null   bool
#  15  title_length           3666 non-null   int64
#  16  rel_year               3666 non-null   int64
#  17  rel_month              3666 non-null   object
# dtypes: bool(2), float64(9), int64(4), object(3)
# memory usage: 465.5+ KB

# %% [markdown]
# -> Some columns have missing values (NaN)

# %% [markdown]
# ### Column Information

# %% [markdown]
# __Labels (Target Variable of Prediction)__

# %% [markdown]
# revenue: the movie´s box office revenue in Million USD (MUSD)

# %% [markdown]
# __Feature Variables:__

# %% [markdown]
# - title: movie title (for information purposes only, not to be used in regression)
# - main_genre: the main genre of the movie (e.g. Drama)
# - belongs_to_collection: Whether the movie belongs to a collection/franchise (True) or not (False). Example: Star Wars
# - budget: the movie´s budget in Million USD (MUSD)
# - production_companies: number of involved production companies
# - vote_average: Average vote by preview audience. From 1 (very bad) to 10 (excellent)
# - popularity: the movie´s popularity measured in google searches, social media posts, etc.
# - runtime: runtime of the movie in minutes
# - cast_size: number of actors involved
# - crew_size: number of crew members involved
# - cast_tr: Track Record of the movie´s three main actors (aggregated box-office revenues in MUSD prior to this movie)
# - director_tr: Track Record of the movie´s director (aggregated box-office revenues in MUSD prior to this movie)
# - production_company_tr: Track Record of the movie´s production company (aggregated box-office revenues in MUSD prior to this movie)
# - English: Whether the movie´s original language is English (True) or not (False)
# - title_length: number of characters in the movie title
# - rel_year: the movie´s year of release
# - rel_month: the movie´s month of release

# %%
df.describe()
# Out:
#             budget      revenue  production_companies  vote_average  \
# count  3666.000000  3666.000000           3521.000000   3662.000000
# mean     37.967148   105.421380              3.513206      6.213053
# std      45.120849   185.822130              2.332797      0.865616
# min       0.000001     0.000001              1.000000      1.000000
# 25%       8.000000     8.006743              2.000000      5.700000
# 50%      21.000000    38.029167              3.000000      6.200000
# 75%      50.000000   116.463053              5.000000      6.800000
# max     380.000000  2787.965087             26.000000      9.000000
#
#         popularity      runtime    cast_size    crew_size       cast_tr  \
# count  3666.000000  3654.000000  3666.000000  3666.000000   3657.000000
# mean     10.458992   109.718664    24.468631    33.419531   1894.761487
# std      16.089384    20.448749    21.002806    36.928229   2341.460368
# min       0.001880    42.000000     0.000000     0.000000      0.000000
# 25%       5.858285    95.000000    13.000000    10.000000    130.577558
# 50%       8.718403   106.000000    18.000000    19.000000    991.792599
# 75%      12.114949   120.000000    28.000000    44.000000   2819.038392
# max     547.488298   338.000000   224.000000   435.000000  20450.834225
#
#        director_tr  production_company_tr  title_length     rel_year
# count  3661.000000            3521.000000   3666.000000  3666.000000
# mean    290.398374            5726.472446     13.135843  2008.168031
# std     708.296750            9916.842612      6.884674     5.330202
# min       0.000000               0.000000      1.000000  1998.000000
# 25%       0.000000               0.173066      9.000000  2004.000000
# 50%      17.496992             357.182732     12.000000  2009.000000
# 75%     262.598896            6396.978333     16.000000  2013.000000
# max    9073.275833           46180.723661     72.000000  2017.000000

# %%
df.hist(figsize = (15, 12), bins = 50)
plt.show()

# %% [markdown]
# ###  Split the Dataset into a Training Set and a Test Set

# %%
df.drop(columns = "title", inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df, test_size = 0.25, shuffle = True, random_state = 42)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2749 entries, 3325 to 3174
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   main_genre             2744 non-null   object
#  1   belongs_to_collection  2749 non-null   bool
#  2   budget                 2749 non-null   float64
#  3   revenue                2749 non-null   float64
#  4   production_companies   2633 non-null   float64
#  5   vote_average           2745 non-null   float64
#  6   popularity             2749 non-null   float64
#  7   runtime                2739 non-null   float64
#  8   cast_size              2749 non-null   int64
#  9   crew_size              2749 non-null   int64
#  10  cast_tr                2741 non-null   float64
#  11  director_tr            2745 non-null   float64
#  12  production_company_tr  2633 non-null   float64
#  13  English                2749 non-null   bool
#  14  title_length           2749 non-null   int64
#  15  rel_year               2749 non-null   int64
#  16  rel_month              2749 non-null   object
# dtypes: bool(2), float64(9), int64(4), object(2)
# memory usage: 349.0+ KB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917 entries, 1960 to 2822
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   main_genre             914 non-null    object
#  1   belongs_to_collection  917 non-null    bool
#  2   budget                 917 non-null    float64
#  3   revenue                917 non-null    float64
#  4   production_companies   888 non-null    float64
#  5   vote_average           917 non-null    float64
#  6   popularity             917 non-null    float64
#  7   runtime                915 non-null    float64
#  8   cast_size              917 non-null    int64
#  9   crew_size              917 non-null    int64
#  10  cast_tr                916 non-null    float64
#  11  director_tr            916 non-null    float64
#  12  production_company_tr  888 non-null    float64
#  13  English                917 non-null    bool
#  14  title_length           917 non-null    int64
#  15  rel_year               917 non-null    int64
#  16  rel_month              917 non-null    object
# dtypes: bool(2), float64(9), int64(4), object(2)
# memory usage: 116.4+ KB

# %% [markdown]
# ### Explanatory Data Analysis (EDA) - Correlations and Regressionplots

# %%
corr_matrix = train_set.corr(numeric_only = True)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,12))
sns.heatmap(corr_matrix, square=True, annot = True, cmap = "RdBu", center = 0, vmax = 0.8)
plt.show()

# %% [markdown]
# -> budget shows the strongest correlation with revenue.

# %%
features = ["budget", "belongs_to_collection", "popularity", "crew_size"]
for i in features:
    sns.lmplot(x = i, y = "revenue", data = train_set)
    plt.show()
# Out:
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Explanatory Data Analysis (EDA) - Categorical Data

# %%
categoricals = train_set.select_dtypes(exclude=np.number).columns.tolist()
categoricals
# Out:
# ['main_genre', 'belongs_to_collection', 'English', 'rel_month']

# %%
categoricals.append("rel_year")

# %%
for cat in categoricals:
    sns.catplot(x = cat, y = "revenue", data = train_set, kind = "bar", aspect = 2)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/jontziv/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Prepare the Data for Data Preprocessing

# %% [markdown]
# Extract X_train, y_train, X_test, and y_test from train_set and test_set by separating the target variable revenue from the feature variables. Identify and save the names of numerical features and text/categorical features (excluding boolean features).

# %%
target = "revenue"

# %%
features = train_set.drop(columns = [target]).columns.to_list()
features
# Out:
# ['main_genre',
#  'belongs_to_collection',
#  'budget',
#  'production_companies',
#  'vote_average',
#  'popularity',
#  'runtime',
#  'cast_size',
#  'crew_size',
#  'cast_tr',
#  'director_tr',
#  'production_company_tr',
#  'English',
#  'title_length',
#  'rel_year',
#  'rel_month']

# %%
X_train = train_set[features].copy()
y_train = train_set[target].copy()
X_test = test_set[features].copy()
y_test = test_set[target].copy()

# %%
numeric_feat = list(X_train.select_dtypes(include = np.number).columns)
numeric_feat
# Out:
# ['budget',
#  'production_companies',
#  'vote_average',
#  'popularity',
#  'runtime',
#  'cast_size',
#  'crew_size',
#  'cast_tr',
#  'director_tr',
#  'production_company_tr',
#  'title_length',
#  'rel_year']

# %%
text_feat = list(X_train.select_dtypes(include = "object").columns)
text_feat
# Out:
# ['main_genre', 'rel_month']

# %% [markdown]
# ### Data Preprocessing Pipeline

# %% [markdown]
# Creating a Data Preprocessing Pipeline (ColumnTransformer) that transforms numerical and categorical features separately and that passes through boolean features:
#
# - numerical Features: Use a scaler that is robust to outliers. Fill missing values (NaN) with the median value.
#
# - categorical features: Use One-Hot-Encoding. Fill missing values (NaN) with the most frequent value.
#
# - boolean features: shall be passed through

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy = "median")),
    ("scaler", RobustScaler())
])

# %%
cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy = "most_frequent")),
    ("encoder", OneHotEncoder())
])

# %%
preprocessor = ColumnTransformer(transformers=
                                 [('num',num_pipeline, numeric_feat), 
                                  ('cat', cat_pipeline, text_feat)
                                 ], remainder = "passthrough"
                                )

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', RobustScaler())]),
#                                  ['budget', 'production_companies',
#                                   'vote_average', 'popularity', 'runtime',
#                                   'cast_size', 'crew_size', 'cast_tr',
#                                   'director_tr', 'production_company_tr',
#                                   'title_length', 'rel_year']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder', OneHotEncoder())]),
#                                  ['main_genre', 'rel_month'])])

# %% [markdown]
# ### Initialize an XGBoost Regression Model and create the Regression Pipeline

# %%
from xgboost import XGBRegressor
model = XGBRegressor(random_state = 42, tree_method = "hist")

# %%
regressor = Pipeline(steps=
                     [("preprocessor", preprocessor),
                      ("model", model)
                     ])

# %%
regressor
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['budget',
#                                                    'production_companies',
#                                                    'vote_average', 'popularity',
#                                                    'runtime', 'cast_size',
#                                                    'crew_size', 'cast_tr',
#                                                    'director_tr',
#                                                    'production_company_tr',
#                                                    'title_length',
#                                                    'rel_yea...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
regressor.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('num',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('scaler', RobustScaler())]),
#                                     ['budget', 'production_companies',
#                                      'vote_average', 'popularity', 'runtime',
#                                      'cast_size', 'crew_size', 'cast_tr',
#                                      'director_tr', 'production_company_tr',
#                                      'title_length', 'rel_year']),
#                                    ('cat',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('encoder', OneHotEncoder())]),
#                                     ['main_genre', 'rel_month'])])),
#   ('model',
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=42, ...))],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(remainder='passthrough',
#                    transformers=[('num',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('scaler', RobustScaler())]),
#                                   ['budget', 'production_companies',
#                                    'vote_average', 'popularity', 'runtime',
#                                    'cast_size', 'crew_size', 'cast_tr',
#                                    'director_tr', 'production_company_tr',
#                                    'title_length', 'rel_year']),
#                                  ('cat',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('encoder', OneHotEncoder())]),
#                                   ['main_genre', 'rel_month'])]),
#  'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'passthrough',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('num',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                    ('scaler', RobustScaler())]),
#    ['budget',
#     'production_companies',
#     'vote_average',
#     'popularity',
#     'runtime',
#     'cast_size',
#     'crew_size',
#     'cast_tr',
#     'director_tr',
#     'production_company_tr',
#     'title_length',
#     'rel_year']),
#   ('cat',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                    ('encoder', OneHotEncoder())]),
#    ['main_genre', 'rel_month'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__num': Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                  ('scaler', RobustScaler())]),
#  'preprocessor__cat': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                  ('encoder', OneHotEncoder())]),
#  'preprocessor__num__memory': None,
#  'preprocessor__num__steps': [('imputer', SimpleImputer(strategy='median')),
#   ('scaler', RobustScaler())],
#  'preprocessor__num__verbose': False,
#  'preprocessor__num__imputer': SimpleImputer(strategy='median'),
#  'preprocessor__num__scaler': RobustScaler(),
#  'preprocessor__num__imputer__add_indicator': False,
#  'preprocessor__num__imputer__copy': True,
#  'preprocessor__num__imputer__fill_value': None,
#  'preprocessor__num__imputer__keep_empty_features': False,
#  'preprocessor__num__imputer__missing_values': nan,
#  'preprocessor__num__imputer__strategy': 'median',
#  'preprocessor__num__scaler__copy': True,
#  'preprocessor__num__scaler__quantile_range': (25.0, 75.0),
#  'preprocessor__num__scaler__unit_variance': False,
#  'preprocessor__num__scaler__with_centering': True,
#  'preprocessor__num__scaler__with_scaling': True,
#  'preprocessor__cat__memory': None,
#  'preprocessor__cat__steps': [('imputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('encoder', OneHotEncoder())],
#  'preprocessor__cat__verbose': False,
#  'preprocessor__cat__imputer': SimpleImputer(strategy='most_frequent'),
#  'preprocessor__cat__encoder': OneHotEncoder(),
#  'preprocessor__cat__imputer__add_indicator': False,
#  'preprocessor__cat__imputer__copy': True,
#  'preprocessor__cat__imputer__fill_value': None,
#  'preprocessor__cat__imputer__keep_empty_features': False,
#  'preprocessor__cat__imputer__missing_values': nan,
#  'preprocessor__cat__imputer__strategy': 'most_frequent',
#  'preprocessor__cat__encoder__categories': 'auto',
#  'preprocessor__cat__encoder__drop': None,
#  'preprocessor__cat__encoder__dtype': numpy.float64,
#  'preprocessor__cat__encoder__feature_name_combiner': 'concat',
#  'preprocessor__cat__encoder__handle_unknown': 'error',
#  'preprocessor__cat__encoder__max_categories': None,
#  'preprocessor__cat__encoder__min_frequency': None,
#  'preprocessor__cat__encoder__sparse': 'deprecated',
#  'preprocessor__cat__encoder__sparse_output': True,
#  'model__objective': 'reg:squarederror',
#  'model__base_score': None,
#  'model__booster': None,
#  'model__callbacks': None,
#  'model__colsample_bylevel': None,
#  'model__colsample_bynode': None,
#  'model__colsample_bytree': None,
#  'model__device': None,
#  'model__early_stopping_rounds': None,
#  'model__enable_categorical': False,
#  'model__eval_metric': None,
#  'model__feature_types': None,
#  'model__gamma': None,
#  'model__grow_policy': None,
#  'model__importance_type': None,
#  'model__interaction_constraints': None,
#  'model__learning_rate': None,
#  'model__max_bin': None,
#  'model__max_cat_threshold': None,
#  'model__max_cat_to_onehot': None,
#  'model__max_delta_step': None,
#  'model__max_depth': None,
#  'model__max_leaves': None,
#  'model__min_child_weight': None,
#  'model__missing': nan,
#  'model__monotone_constraints': None,
#  'model__multi_strategy': None,
#  'model__n_estimators': None,
#  'model__n_jobs': None,
#  'model__num_parallel_tree': None,
#  'model__random_state': 42,
#  'model__reg_alpha': None,
#  'model__reg_lambda': None,
#  'model__sampling_method': None,
#  'model__scale_pos_weight': None,
#  'model__subsample': None,
#  'model__tree_method': 'hist',
#  'model__validate_parameters': None,
#  'model__verbosity': None}

# %% [markdown]
# ### Perform Hyperparameter Tuning using Cross Validation

# %% [markdown]
# Perform Hyperparameter Tuning using Randomized Search Cross Validation (60 random parameter settings with random_State = 42) on the Training Set. To evaluate model performance, calculate the regression scores RMSE (root mean squared error) and R-squared (coefficient of determination). Finally, refit the best model with the lowest RMSE score.
#
# Tuning shall include the following XGBRegressor Hyperparameters: max_depth, n_estimators, learning_rate, colsample_bytree, subsample, min_child_weight, gamma, reg_alpha, and reg_lambda.

# %%
param_grid = [{"model__max_depth": [3, 4, 5, 6, 7, 8, 9, 10],
               "model__n_estimators": [100, 150, 200],
               "model__learning_rate": [0.01, 0.03, 0.05, 0.07, 0.09, 0.11],
               "model__colsample_bytree": [0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1],
               "model__subsample": [0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1],
               "model__min_child_weight": [1, 3, 5, 7, 9, 11, 13],
               "model__gamma": [0, 1, 2, 3, 4, 5],
               "model__reg_alpha": [0, 0.1, 0.3, 0.5, 0.7, 0.9, 1],
               "model__reg_lambda": [0, 0.1, 0.3, 0.5, 0.7, 0.9, 1],
              }]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_iter = 60
n_jobs = -1 
scores = ["neg_root_mean_squared_error", "r2"]
refit = "neg_root_mean_squared_error" 
random_state = 42

# %%
rscv = RandomizedSearchCV(estimator = regressor, 
                          param_distributions = param_grid, 
                          n_iter = n_iter,
                          n_jobs = n_jobs, 
                          scoring = scores,
                          refit = refit, 
                          random_state = random_state)

# %%
rscv.fit(X = X_train, y = y_train)
# Out:
# RandomizedSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 RobustScaler())]),
#                                                                                ['budget',
#                                                                                 'production_companies',
#                                                                                 'vote_average',
#                                                                                 'popularity',
#                                                                                 'runtime',
#                                                                                 'cast_size',
#                                                                                 'crew_size',
#                                                                                 'cast_tr',
#                                                                                 'director_tr',
#                                                                                 'production_compan...
#                                          'model__max_depth': [3, 4, 5, 6, 7, 8,
#                                                               9, 10],
#                                          'model__min_child_weight': [1, 3, 5, 7,
#                                                                      9, 11,
#                                                                      13],
#                                          'model__n_estimators': [100, 150, 200],
#                                          'model__reg_alpha': [0, 0.1, 0.3, 0.5,
#                                                               0.7, 0.9, 1],
#                                          'model__reg_lambda': [0, 0.1, 0.3, 0.5,
#                                                                0.7, 0.9, 1],
#                                          'model__subsample': [0.3, 0.5, 0.6,
#                                                               0.7, 0.8, 0.9,
#                                                               1]}],
#                    random_state=42, refit='neg_root_mean_squared_error',
#                    scoring=['neg_root_mean_squared_error', 'r2'])

# %% [markdown]
# ### Evaluate Cross Validation and select the best Model

# %%
rscv.best_params_
# Out:
# {'model__subsample': 1,
#  'model__reg_lambda': 0.5,
#  'model__reg_alpha': 0,
#  'model__n_estimators': 150,
#  'model__min_child_weight': 11,
#  'model__max_depth': 6,
#  'model__learning_rate': 0.07,
#  'model__gamma': 0,
#  'model__colsample_bytree': 0.7}

# %%
rscv.best_score_
# Out:
# -95.27050948563357

# %%
cv_results = pd.DataFrame(rscv.cv_results_)[["params",
                                            "mean_test_neg_root_mean_squared_error",
                                            "mean_test_r2",
                                            "rank_test_neg_root_mean_squared_error",
                                            "rank_test_r2"]]

# %%
cv_results = cv_results.sort_values("mean_test_neg_root_mean_squared_error", ascending=False)
cv_results
# Out:
#                                                params  \
# 0   {'model__subsample': 1, 'model__reg_lambda': 0...
# 33  {'model__subsample': 0.6, 'model__reg_lambda':...
# 45  {'model__subsample': 0.9, 'model__reg_lambda':...
# 7   {'model__subsample': 1, 'model__reg_lambda': 0...
# 24  {'model__subsample': 0.9, 'model__reg_lambda':...
# 52  {'model__subsample': 1, 'model__reg_lambda': 0...
# 19  {'model__subsample': 0.7, 'model__reg_lambda':...
# 38  {'model__subsample': 0.7, 'model__reg_lambda':...
# 49  {'model__subsample': 0.5, 'model__reg_lambda':...
# 32  {'model__subsample': 0.9, 'model__reg_lambda':...
# 15  {'model__subsample': 0.8, 'model__reg_lambda':...
# 56  {'model__subsample': 0.8, 'model__reg_lambda':...
# 21  {'model__subsample': 0.9, 'model__reg_lambda':...
# 31  {'model__subsample': 0.8, 'model__reg_lambda':...
# 12  {'model__subsample': 0.9, 'model__reg_lambda':...
# 43  {'model__subsample': 0.9, 'model__reg_lambda':...
# 35  {'model__subsample': 0.9, 'model__reg_lambda':...
# 36  {'model__subsample': 1, 'model__reg_lambda': 0...
# 3   {'model__subsample': 1, 'model__reg_lambda': 0...
# 55  {'model__subsample': 0.7, 'model__reg_lambda':...
# 11  {'model__subsample': 0.7, 'model__reg_lambda':...
# 25  {'model__subsample': 0.8, 'model__reg_lambda':...
# 9   {'model__subsample': 0.5, 'model__reg_lambda':...
# 16  {'model__subsample': 0.5, 'model__reg_lambda':...
# 51  {'model__subsample': 0.7, 'model__reg_lambda':...
# 1   {'model__subsample': 1, 'model__reg_lambda': 0...
# 48  {'model__subsample': 0.5, 'model__reg_lambda':...
# 30  {'model__subsample': 0.9, 'model__reg_lambda':...
# 20  {'model__subsample': 0.5, 'model__reg_lambda':...
# 34  {'model__subsample': 0.3, 'model__reg_lambda':...
# 57  {'model__subsample': 0.5, 'model__reg_lambda':...
# 29  {'model__subsample': 0.3, 'model__reg_lambda':...
# 26  {'model__subsample': 1, 'model__reg_lambda': 0...
# 37  {'model__subsample': 0.5, 'model__reg_lambda':...
# 44  {'model__subsample': 0.6, 'model__reg_lambda':...
# 53  {'model__subsample': 1, 'model__reg_lambda': 0...
# 50  {'model__subsample': 0.6, 'model__reg_lambda':...
# 10  {'model__subsample': 0.9, 'model__reg_lambda':...
# 42  {'model__subsample': 0.7, 'model__reg_lambda':...
# 47  {'model__subsample': 0.8, 'model__reg_lambda':...
# 28  {'model__subsample': 0.6, 'model__reg_lambda':...
# 8   {'model__subsample': 0.8, 'model__reg_lambda':...
# 4   {'model__subsample': 0.3, 'model__reg_lambda':...
# 5   {'model__subsample': 0.9, 'model__reg_lambda':...
# 14  {'model__subsample': 0.3, 'model__reg_lambda':...
# 40  {'model__subsample': 0.9, 'model__reg_lambda':...
# 27  {'model__subsample': 1, 'model__reg_lambda': 0...
# 6   {'model__subsample': 0.5, 'model__reg_lambda':...
# 22  {'model__subsample': 0.3, 'model__reg_lambda':...
# 18  {'model__subsample': 0.7, 'model__reg_lambda':...
# 23  {'model__subsample': 0.5, 'model__reg_lambda':...
# 54  {'model__subsample': 0.8, 'model__reg_lambda':...
# 41  {'model__subsample': 0.7, 'model__reg_lambda':...
# 39  {'model__subsample': 0.7, 'model__reg_lambda':...
# 58  {'model__subsample': 0.7, 'model__reg_lambda':...
# 46  {'model__subsample': 0.8, 'model__reg_lambda':...
# 59  {'model__subsample': 0.6, 'model__reg_lambda':...
# 2   {'model__subsample': 0.3, 'model__reg_lambda':...
# 13  {'model__subsample': 0.7, 'model__reg_lambda':...
# 17  {'model__subsample': 0.3, 'model__reg_lambda':...
#
#     mean_test_neg_root_mean_squared_error  mean_test_r2  \
# 0                              -95.270509      0.748063
# 33                             -95.337598      0.748893
# 45                             -95.403102      0.746496
# 7                              -95.990204      0.744715
# 24                             -96.438810      0.742090
# 52                             -96.442799      0.742706
# 19                             -96.485614      0.742575
# 38                             -96.509356      0.742437
# 49                             -96.642119      0.739928
# 32                             -96.673843      0.740894
# 15                             -96.907872      0.740194
# 56                             -96.979468      0.738538
# 21                             -97.050318      0.737700
# 31                             -97.105709      0.738849
# 12                             -97.168257      0.737812
# 43                             -97.213685      0.738475
# 35                             -97.316431      0.738113
# 36                             -97.404893      0.736673
# 3                              -97.488464      0.737162
# 55                             -97.499255      0.736209
# 11                             -97.682037      0.735740
# 25                             -97.817737      0.735527
# 9                              -98.100213      0.732650
# 16                             -98.211196      0.732397
# 51                             -98.384233      0.731303
# 1                              -98.440268      0.730542
# 48                             -98.476403      0.730992
# 30                             -98.544599      0.730051
# 20                             -98.595990      0.729175
# 34                             -98.661789      0.731009
# 57                             -98.890020      0.729633
# 29                             -98.976563      0.729103
# 26                             -99.002071      0.728079
# 37                             -99.016466      0.728778
# 44                             -99.111285      0.727705
# 53                             -99.166536      0.727749
# 50                             -99.176798      0.725635
# 10                             -99.258073      0.726222
# 42                             -99.260469      0.727825
# 47                             -99.326269      0.726069
# 28                             -99.372193      0.726547
# 8                              -99.397130      0.726307
# 4                              -99.698350      0.725124
# 5                              -99.849599      0.724367
# 14                             -99.855897      0.723716
# 40                            -100.162446      0.721123
# 27                            -100.175185      0.722610
# 6                             -100.436013      0.718450
# 22                            -101.500353      0.715398
# 18                            -102.046542      0.712448
# 23                            -102.182733      0.711161
# 54                            -103.107637      0.706215
# 41                            -103.333233      0.705144
# 39                            -104.876557      0.696425
# 58                            -105.825428      0.691033
# 46                            -105.860030      0.690675
# 59                            -106.026921      0.689721
# 2                             -120.971407      0.595985
# 13                            -123.703541      0.577470
# 17                            -134.868277      0.497778
#
#     rank_test_neg_root_mean_squared_error  rank_test_r2
# 0                                       1             2
# 33                                      2             1
# 45                                      3             3
# 7                                       4             4
# 24                                      5             8
# 52                                      6             5
# 19                                      7             6
# 38                                      8             7
# 49                                      9            11
# 32                                     10             9
# 15                                     11            10
# 56                                     12            13
# 21                                     13            17
# 31                                     14            12
# 12                                     15            16
# 43                                     16            14
# 35                                     17            15
# 36                                     18            19
# 3                                      19            18
# 55                                     20            20
# 11                                     21            21
# 25                                     22            22
# 9                                      23            23
# 16                                     24            24
# 51                                     25            25
# 1                                      26            28
# 48                                     27            27
# 30                                     28            29
# 20                                     29            31
# 34                                     30            26
# 57                                     31            30
# 29                                     32            32
# 26                                     33            34
# 37                                     34            33
# 44                                     35            37
# 53                                     36            36
# 50                                     37            42
# 10                                     38            40
# 42                                     39            35
# 47                                     40            41
# 28                                     41            38
# 8                                      42            39
# 4                                      43            43
# 5                                      44            44
# 14                                     45            45
# 40                                     46            47
# 27                                     47            46
# 6                                      48            48
# 22                                     49            49
# 18                                     50            50
# 23                                     51            51
# 54                                     52            52
# 41                                     53            53
# 39                                     54            54
# 58                                     55            55
# 46                                     56            56
# 59                                     57            57
# 2                                      58            58
# 13                                     59            59
# 17                                     60            60

# %%
rscv.best_estimator_[1]
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=11, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=150, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ## Evaluate model performance on the Testset

# %%
pred = rscv.predict(X_test)
pred
# Out:
# array([ 9.58642578e+00,  2.51282787e+01,  1.07070663e+02,  2.60866985e+01,
#         4.15633583e+01,  3.91973419e+02,  2.04689140e+01,  1.37654877e+02,
#         1.06347322e+01,  1.40656052e+02,  1.74395905e+01,  9.07483749e+01,
#         8.55860138e+01,  1.92956696e+02,  1.11586479e+02,  2.00081131e+02,
#         2.33811768e+02,  5.78913841e+01,  3.27664795e+02,  3.95198784e+01,
#         1.35494843e+02,  3.76953186e+02,  7.68365326e+01,  1.59915638e+01,
#         2.28574681e+00,  3.05597748e+02,  6.25256586e+00,  4.34978218e+01,
#         2.25465355e+01,  5.78168678e+01,  1.31523941e+02,  1.08072365e+02,
#         9.12048492e+01,  9.23923889e+02,  9.28292847e+00,  4.06359367e+01,
#         7.64950180e+01,  2.11907921e+01,  5.45053825e+01,  2.38724594e+01,
#         3.90791351e+02,  1.04216911e+02,  2.84440098e+01,  9.76237869e+00,
#         7.82362442e+01,  3.99684715e+01,  6.93936646e+02,  8.00337887e+00,
#         1.29903736e+01,  4.02550598e+02,  3.73770386e+02,  2.10714752e+02,
#         5.86481209e+01,  7.32843094e+01,  1.81273041e+02,  6.40283356e+01,
#         1.46990311e+00,  6.28894768e+01,  1.06472645e+01,  2.78820457e+01,
#         1.01443123e+02,  4.60783958e+01,  1.29536057e+02,  4.46894775e+02,
#         3.03047562e+00,  2.07273071e+02,  4.00620232e+01,  3.73339500e+01,
#         3.47509003e+00,  3.14451599e+00,  1.73090954e+01,  2.00244370e+02,
#         7.59679260e+01,  1.08817741e+02,  3.11142456e+02,  8.81423828e+02,
#         3.56950775e+02,  4.04100657e+00,  1.52661333e+01,  1.87123108e+01,
#         2.54788399e+01,  7.73661499e+01,  2.18693161e+02,  1.77623787e+01,
#         9.29679794e+01,  3.01164112e+01,  3.07422676e+01,  1.26442490e+02,
#         2.40568733e+01,  1.02456484e+01,  5.21119766e+01,  1.88493362e+02,
#         1.26823835e+01,  4.57997274e+00,  2.21185799e+01,  4.52420692e+01,
#         1.40359964e+01,  1.22388562e+03,  1.55702011e+02,  6.80218649e+00,
#         2.34395647e+00,  3.11189850e+02,  1.28810854e+01,  9.44195080e+00,
#         3.75487061e+01,  3.77003975e+01,  5.11523773e+02,  1.37793457e+02,
#         8.26949921e+01,  1.41878616e+02,  4.80523346e+02,  6.26631836e+02,
#         2.56407261e+01,  7.66076813e+01,  1.50447617e+02,  2.81149483e+01,
#         2.19452667e+02,  2.66171875e+01,  3.22820778e+01,  1.73408340e+02,
#         2.57251038e+02,  3.09617977e+01,  5.57472289e-01,  8.81358276e+02,
#         6.99877625e+01,  2.10868393e+02,  1.85185349e+02,  5.97362862e+01,
#         8.86682892e+01,  1.81842789e+02,  6.96477417e+02,  6.97731733e+00,
#         9.15280247e+00,  2.16522720e+02,  4.89685965e+00,  1.21618977e+01,
#         6.21888618e+01,  1.82408569e+02,  7.83705368e+01,  3.15490936e+02,
#         1.75057938e+02,  7.60554695e+00,  1.20428028e+01,  3.74931221e+01,
#         1.91918697e+01,  9.46042480e+02,  1.25990677e+01,  7.25277710e+01,
#         2.11789459e+02,  1.14570511e+02,  5.98834572e+01,  2.31511116e+01,
#         1.23723059e+01,  1.47047768e+01,  1.43031282e+01,  1.87115402e+01,
#         2.08849125e+01,  3.60569336e+02,  2.66884494e+00,  1.33689926e+02,
#         9.73934708e+01,  8.97179565e+01,  1.40015936e+01,  5.83336973e+00,
#         5.86528740e+01], dtype=float32)

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y_true = y_test, y_pred = pred, squared = False)
# Out:
# 90.74906576701176

# %%
metrics.r2_score(y_true = y_test, y_pred = pred)
# Out:
# 0.7166235639135503

# %% [markdown]
# -> In line with Cross Validation results (RMSE score better, R-squared score slightly worse)
